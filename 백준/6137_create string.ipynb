# %% [markdown]
# 제출

# %%
from collections import deque

def chk_LR(left_p,right_p):
    if left_p<=right_p:
        if string[left_p]>string[right_p]:
            return "right"
        elif string[left_p]<string[right_p]:
            return "left"
        else : 
            return chk_LR(left_p+1,right_p-1)
    else :
        return "left"
    
n=int(input())
string=[]
for _ in range(n):
    string+=input().rstrip()

left_p  = 0
right_p = n-1
c=0
while c<n:
    c+=1
    drtn = chk_LR(left_p,right_p)
    if drtn == "right": 
        print(string[right_p], end ='')
        right_p-=1
    elif drtn == "left":
        print(string[left_p], end='')
        left_p+=1
        
    if c%80==0:
        print()
# Out:
# 4
# B
# A
# B
# A
# ABAB

# %%
from collections import deque

string ="AAKKDKEKKCMKMDKQLAKCJKAKAKDJFFFFFKKAKAAASSSOOEOEEEPPPDDDDDDDAA"
n=len(string)
s=deque([i for i in string])
print(s)
answers=[]

def compare(n, m):
    answer = True
    while n <= m:
        if s[n] == s[m]:
            n += 1
            m -= 1
        elif s[n] < s[m]:
            return True
        else:
            return False
    return answer

while s:
    answers.append(s.popleft()) if compare(0, len(s)-1) else answers.append(s.pop())

print(''.join(answers))
# Out:
# deque(['A', 'A', 'K', 'K', 'D', 'K', 'E', 'K', 'K', 'C', 'M', 'K', 'M', 'D', 'K', 'Q', 'L', 'A', 'K', 'C', 'J', 'K', 'A', 'K', 'A', 'K', 'D', 'J', 'F', 'F', 'F', 'F', 'F', 'K', 'K', 'A', 'K', 'A', 'A', 'A', 'S', 'S', 'S', 'O', 'O', 'E', 'O', 'E', 'E', 'E', 'P', 'P', 'P', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'A', 'A'])
# AAAADDDDDDDKKDKEKKCMKMDKPPPEEEOEOOQLAKCJKAKAKDJFFFFFKKAKAAASSS

# %%
from collections import deque

def chk_LR(left_p,right_p,s=0):
    if s==0:
        if string[left_p]>string[right_p]:
            return "right"
        elif string[left_p]<string[right_p]:
            return "left"
        else : return "equal"
    else: 
        if string[left_p+s]==string[right_p-s]:
            if string[left_p+s]>string[left_p] and string[right_p-s]>string[right_p]:
                return "equal_next"
            else :
                return "equal"
        else :
            return chk_LR(left_p+s,right_p-s,0)
        
n=int(input())
string=[]
for _ in range(n):
    string+=input()
    
left_p  = 0
right_p = n-1
c=0
s=0
while c<n:
    c+=1
    drtn = chk_LR(left_p,right_p,s)
    if drtn == "right": 
        print(string[right_p-s], end ='')
        right_p-=s+1
        s=0
    elif drtn == "left":
        print(string[left_p+s], end='')
        left_p+=s+1
        s=0
    elif drtn == "equal" : 
        print(string[left_p+s], end='')
        s+=1
    elif drtn == "equal_next":
        print(string[left_p], end='')
        left_p+=s
        right_p-=s
        s=0

    if c==3:
        print()
# Out:
# 10
#
# D
# D
# B
# C
# A
# S
# E
# W
# E
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-193-bd2588e0c8f1> in <module>
#      28 while c<n:
#      29     c+=1
# ---> 30     drtn = chk_LR(left_p,right_p,s)
#      31     if drtn == "right":
#      32         print(string[right_p-s], end ='')
#
# <ipython-input-193-bd2588e0c8f1> in chk_LR(left_p, right_p, s)
#       3 def chk_LR(left_p,right_p,s=0):
#       4     if s==0:
# ----> 5         if string[left_p]>string[right_p]:
#       6             return "right"
#       7         elif string[left_p]<string[right_p]:
#
# IndexError: list index out of range

# %%
from collections import deque

def chk_LR(left_p,right_p,s=0):
    if s==0:
        if string[left_p]>string[right_p]:
            return "right"
        elif string[left_p]<string[right_p]:
            return "left"
        else : return "equal"
    else: 
        if string[left_p+s]==string[right_p-s]:
            return "equal"
        else :
            return chk_LR(left_p+s,right_p-s,0)
        
n=int(input())
string=[]
for _ in range(n):
    string+=input()

left_p  = 0
right_p = n-1
c=0
s=0
while c<n:
    c+=1
    drtn = chk_LR(left_p,right_p,s)
    if drtn == "right": 
        print(string[right_p-s], end ='')
        right_p-=s+1
        s=0
    elif drtn == "left":
        print(string[left_p+s], end='')
        left_p+=s+1
        s=0
    elif drtn == "equal" : 
        print(string[left_p+s], end='')
        s+=1
        
    if c==80:
        print()

# %%
from collections import deque

n=int(input())
string=[]
for _ in range(n):
    string+=input()

left_p  = 0
right_p = n-1
c=0
s=0
while c<n:
    c+=1
    
    if string[left_p]>string[right_p]:
        print(string[right_p], end ='')
        left_p-=s
        right_p-=1
        s=0
    elif string[left_p]<string[right_p]:
        print(string[left_p], end ='')
        left_p+=1
        right_p+=s
        s=0
    else : 
        print(string[left_p], end ='')
        if string[left_p]>string[left_p+1]:
            right_p-=1
        elif string[right_p]<string[right_p-1]:
            left_p+=1
        else:
            right_p-=1
            left_p+=1
            s+=1
    if c==80:
        print()

# %%
from collections import deque

n=int(input())
string=[]
for _ in range(n):
    string+=input()

left_p  = 0
right_p = n-1
tag_left = left_p
tag_right = right_p
tag_st = True
c=0
while c<n:
    c+=1
    if string[left_p]>string[right_p]:
        print(string[right_p], end ='')
        right_p-=1
        if not tag_st:
            left_p=tag_left
            tag_st=True
    elif string[left_p]<string[right_p]:
        print(string[left_p], end ='')
        left_p+=1
        if not tag_st:
            right_p=tag_right
            tag_st=True
    else :
        if tag_st:
            tag_left=left_p
            tag_right=right_p
            tag_st = False
        print(string[right_p], end ='')
        left_p+=1
        right_p-=1
    if c==80:
        print()

# %%
#NG
from collections import deque

n=int(input())
string=[]
for _ in range(n):
    string+=input()

string+='Z'
answer=[-1 for _ in range(n)]
left_p  = 0
right_p = n-1
i=0
q=deque()
q.append((i,left_p,right_p))


while q:
    i,left_p,right_p=q.popleft()
    
    if left_p==right_p: answer[i]=right_p; break
    if string[left_p]>string[right_p]:
        if string[answer[i]]>=string[right_p] and right_p not in answer: 
            answer[i]=right_p
        q.append((i+1,left_p,right_p-1))
    elif string[left_p]<string[right_p] :
        if string[answer[i]]>=string[left_p] and left_p not in answer: 
            answer[i]=left_p
        q.append((i+1,left_p+1,right_p))
    else : 
        if string[answer[i]]>string[left_p]: answer[i]=left_p
        q.append((i+1,left_p,right_p-1))
        q.append((i+1,left_p+1,right_p))
for i in range(n):
    if i!=0 and i%80==0: print()
    print(string[answer[i]], end='')

# %% [markdown]
# Test

# %%
from collections import deque

def chk_LR(left_p,right_p):
    if left_p<=right_p:
        if string[left_p]>string[right_p]:
            return "right"
        elif string[left_p]<string[right_p]:
            return "left"
        else : 
            return chk_LR(left_p+1,right_p-1)
    else :
        return "left"
    
# n=int(input())
# string=[]
# for _ in range(n):
#     string+=input()

n=4
string =''
n=5
string ="BABA"
n=len(string)
left_p  = 0
right_p = n-1
c=0
while c<n:
    c+=1
    drtn = chk_LR(left_p,right_p)
    if drtn == "right": 
        print(string[right_p], end ='')
        right_p-=1
    elif drtn == "left":
        print(string[left_p], end='')
        left_p+=1
    if c%10==0:
        print()
# Out:
# ABAB

# %%
from collections import deque

def chk_LR(left_p,right_p,s=0):
    if s==0:
        if string[left_p]>string[right_p]:
            return "right"
        elif string[left_p]<string[right_p]:
            return "left"
        else : return "equal"
    else: 
        print(left_p+s,right_p-s)
        if string[left_p+s]==string[right_p-s]:
            if string[left_p+s]>string[left_p] and string[right_p-s]>string[right_p]:
                return "equal_next"
            else :
                return "equal"
        else :
            return chk_LR(left_p+s,right_p-s,0)
        
# n=int(input())
# string=[]
# for _ in range(n):
#     string+=input()

n=4
string =''
n=7
string ='CBBBDBC'

left_p  = 0
right_p = n-1
c=0
s=0
while c<n:
    c+=1
    print(c,left_p,right_p,s)
    drtn = chk_LR(left_p,right_p,s)
    if drtn == "right": 
        print(string[right_p-s], end ='')
        right_p-=s+1
        s=0
    elif drtn == "left":
        print(string[left_p+s], end='')
        left_p+=s+1
        s=0
    elif drtn == "equal" : 
        print(string[left_p+s], end='')
        s+=1
    elif drtn == "equal_next":
        print(string[left_p], end='')
        left_p+=s
        right_p-=s
        s=0

    if c==80:
        print()
# Out:
# 1 0 6 0
# C2 0 6 1
# 1 5
# B3 0 6 2
# 2 4
# B4 3 6 0
# B5 4 6 0
# C6 4 5 0
# B7 4 4 0
# D

# %%
from collections import deque

# n=int(input())
# string=[]
# for _ in range(n):
#     string+=input()
n=7
string ='ACAACAC'
left_p  = 0
right_p = n-1
c=0
s=0
while c<n:
    c+=1
    print(c,left_p,right_p)
    if string[left_p]>string[right_p]:
        print(string[right_p], end ='')
        left_p-=s
        right_p-=1
        s=0
    elif string[left_p]<string[right_p]:
        print(string[left_p], end ='')
        left_p+=1
        right_p+=s
        s=0
    else : 
        print(string[left_p], end ='')
        if left_p>=n-1 and right_p<=0: break
            
        if string[left_p+1] == string[right_p-1]:
            if string[left_p]>=string[left_p+1]:
                right_p-=1
                left_p+=1
                s+=1
            else : 
                left_p+=1
        elif string[left_p+1] > string[right_p-1]:
            if string[right_p-1]<=string[right_p]:
                right_p-=1
            else:
                left_p+=1
                
        elif string[left_p+1] < string[right_p-1]:
            if string[left_p+1]<=string[left_p]:
                left_p+=1
            else:
                right_p-=1        

    if c==80:
        print()

#          'ACAACAC'
# Out:
# 1 0 6
# A2 1 6
# C3 2 5
# A4 3 5
# A5 4 5
# A6 3 4
# A7 4 4
# C

# %%
from collections import deque

# n=int(input())
# string=[]
# for _ in range(n):
#     string+=input()
n=7
string ='ACAACAC'
left_p  = 0
right_p = n-1
c=0
s=0
while c<n:
    c+=1
    print(c,left_p,right_p)
    if string[left_p]>string[right_p]:
        print(string[right_p], end ='')
        left_p-=s
        right_p-=1
        s=0
    elif string[left_p]<string[right_p]:
        print(string[left_p], end ='')
        left_p+=1
        right_p+=s
        s=0
    else : 
        print(string[left_p], end ='')
        if left_p>=n-1 and right_p<=0: break
        if string[left_p]>string[left_p+1] and string[left_p+1] != string[right_p-1]:
            right_p-=1
        elif string[right_p]<string[right_p-1] and string[left_p+1] != string[right_p-1]:
            left_p+=1
        else:
            right_p-=1
            left_p+=1
            s+=1
    if c==80:
        print()

#          'ACAACAC'
# Out:
# 1 0 6
# A2 1 6
# C3 2 5
# A4 3 5
# A5 4 4
# C6 5 3
# A7 6 2
# A

# %%
from collections import deque

# n=int(input())
# string=[]
# for _ in range(n):
#     string+=input()
n=4
string ='CDDC'
left_p  = 0
right_p = n-1
tag_left = left_p
tag_right = right_p
tag_st = True
c=0
while c<n:
    c+=1
    if string[left_p]>string[right_p]:
        print(string[right_p], end ='')
        right_p-=1
        if not tag_st:
            left_p=tag_left
            tag_st=True
    elif string[left_p]<string[right_p]:
        print(string[left_p], end ='')
        left_p+=1
        if not tag_st:
            right_p=tag_right
            tag_st=True
    else :
        if tag_st:
            tag_left=left_p
            tag_right=right_p
            tag_st = False
        print(string[right_p], end ='')
        left_p+=1
        right_p-=1
    if c==80:
        print()
# Out:
# CDDC

# %%
def chk(left_p,right_p):
    if string[left_p] < string[right_p]:
        return left_p+1,right_p,string[left_p]
    elif string[left_p] > string[right_p]:
        return left_p,right_p-1,string[right_p]
    
            
from collections import deque

# n=int(input())
# string=[]
# for _ in range(n):
#     string+=input()
n=10
string ='CBDBCDDABC'
left_p  = 0
right_p = n-1
c=0
while c<n:
    c+=1
    temp=()
    if string[left_p]!=string[right_p]:
        temp = chk(left_p,right_p)
        print(temp[2], end ='')
    else : 
        if string[left_p]>string[left_p+1] and string[right_p]>string[right_p-1]:
            temp = chk(left_p+1,right_p-1)
            
        if string[left_p]>string[left_p+1]:
            
        if string[right_p]>string[right_p-1]:
            
        
    if c==80:
        print()
# Out:
# CBACBDBCDDABC
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-87-5bba9f8939d1> in <module>
#      29     sel=-1
#      30     left_t,right_t=left_p,right_p
# ---> 31     left_p,right_p,sel = chk(left_p,right_p,-1)
#      32     if sel == 0: left_p=left_t
#      33     elif sel == 1 : right_p=right_t
#
# <ipython-input-87-5bba9f8939d1> in chk(left_p, right_p, sel)
#       1 def chk(left_p,right_p,sel):
#       2     global c
# ----> 3     if string[left_p]==string[right_p]:
#       4         print(string[right_p], end ='')
#       5         return chk(left_p+1,right_p-1,-1)
#
# IndexError: string index out of range

# %%
from collections import deque

# n=int(input())
# string=[]
# for _ in range(n):
#     string+=input()
n=4
string ='AAAA'
string+='Z'
answer=[-1 for _ in range(n)]
left_p  = 0
right_p = n-1
i=0
q=deque()
q.append((i,left_p,right_p))


while q:
    print(q)
    i,left_p,right_p=q.popleft()
    if string[answer[i]]<string[left_p] and string[answer[i]]<string[right_p]: continue
        
    if left_p==right_p: answer[i]=right_p; break
        
    if string[left_p]>string[right_p]:
        if string[answer[i]]>=string[right_p] and right_p not in answer: 
            answer[i]=right_p
        q.append((i+1,left_p,right_p-1))
    elif string[left_p]<string[right_p] :
        if string[answer[i]]>=string[left_p] and left_p not in answer: 
            answer[i]=left_p
        q.append((i+1,left_p+1,right_p))
    else : 
        if string[answer[i]]>string[left_p]: answer[i]=left_p
        
        q.append((i+1,left_p,right_p-1))
        q.append((i+1,left_p+1,right_p))
for i in range(n):
    if i!=0 and i%80==0: print()
    print(string[answer[i]], end='')
# Out:
# deque([(0, 0, 3)])
# deque([(1, 0, 2), (1, 1, 3)])
# deque([(1, 1, 3), (2, 0, 1), (2, 1, 2)])
# deque([(2, 0, 1), (2, 1, 2), (2, 1, 2), (2, 2, 3)])
# deque([(2, 1, 2), (2, 1, 2), (2, 2, 3), (3, 0, 0), (3, 1, 1)])
# deque([(2, 1, 2), (2, 2, 3), (3, 0, 0), (3, 1, 1), (3, 1, 1), (3, 2, 2)])
# deque([(2, 2, 3), (3, 0, 0), (3, 1, 1), (3, 1, 1), (3, 2, 2), (3, 1, 1), (3, 2, 2)])
# deque([(3, 0, 0), (3, 1, 1), (3, 1, 1), (3, 2, 2), (3, 1, 1), (3, 2, 2), (3, 2, 2), (3, 3, 3)])
# AAAA

# %%
import sys
input = sys.stdin.readline

n=int(input())
string=[]
for _ in range(n):
    string+=input()

left_p  = 0
right_p = n-1
c=0
while left_p != right_p:
    c+=1
    if string[left_p]>=string[right_p]:
        print(string[right_p], end ='')
        right_p-=1
    elif string[left_p]<string[right_p]:
        print(string[left_p], end ='')
        left_p+=1
    if c==80:
        print()
print(string[left_p])

# %%
A
C
D
B
C
B
